# %% [markdown]
# #Noise Removal

# %%
import string

text = "Ugh... The deliveries were DELAYED!! I seriously hate waiting... #annoyed"

text_lower = text.lower()

translator = str.maketrans('','',string.punctuation)
clean_text = text_lower.translate(translator)

print(clean_text)
# Out:
# ugh the deliveries were delayed i seriously hate waiting annoyed

# %% [markdown]
# #Tokenization

# %% [markdown]
# ##simple split

# %%
tokens = clean_text.split()

print(tokens)
# Out:
# ['ugh', 'the', 'deliveries', 'were', 'delayed', 'i', 'seriously', 'hate', 'waiting', 'annoyed']

# %% [markdown]
# ##BERT Tokenizer

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
complex_text = "The microtransactional system was counterintuitive."
print(tokenizer.tokenize(complex_text))
# Out:
# ['the', 'micro', '##tra', '##ns', '##act', '##ional', 'system', 'was', 'counter', '##int', '##uit', '##ive', '.']

# %% [markdown]
# #Stop Word Removal

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [token for token in tokens if token not in stop_words]
print(filtered_tokens)
# Out:
# ['ugh', 'deliveries', 'delayed', 'seriously', 'hate', 'waiting', 'annoyed']

# %% [markdown]
# #Stemming vs Lemmatization

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('wordnet')

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

words = ['deliveries','studies','playing']

for w in words:
  print(w,'|',stemmer.stem(w),'|',lemmatizer.lemmatize(w))
# Out:
# deliveries | deliveri | delivery
# studies | studi | study
# playing | play | playing
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #PRACTICE

# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df = pd.DataFrame({
"raw_text": [
"The food was amazing, and the tea was hot!!!",
"Bad service... I waited 20 minutes for a sandwich?",
"The samosas are tasty but the coffee is too sweet.",
"Cleaning was not good, very dirty tables."
]
})
df.head()
# Out:
#                                             raw_text
# 0       The food was amazing, and the tea was hot!!!
# 1  Bad service... I waited 20 minutes for a sandw...
# 2  The samosas are tasty but the coffee is too sw...
# 3          Cleaning was not good, very dirty tables.

# %%
df['processed'] = df['raw_text'].str.lower()
df
# Out:
#                                             raw_text  \
# 0       The food was amazing, and the tea was hot!!!
# 1  Bad service... I waited 20 minutes for a sandw...
# 2  The samosas are tasty but the coffee is too sw...
# 3          Cleaning was not good, very dirty tables.
#
#                                            processed
# 0       the food was amazing, and the tea was hot!!!
# 1  bad service... i waited 20 minutes for a sandw...
# 2  the samosas are tasty but the coffee is too sw...
# 3          cleaning was not good, very dirty tables.

# %%
translator = str.maketrans('','',string.punctuation)
df['processed'] = df['processed'].apply(lambda x: x.translate(translator))
df
# Out:
#                                             raw_text  \
# 0       The food was amazing, and the tea was hot!!!
# 1  Bad service... I waited 20 minutes for a sandw...
# 2  The samosas are tasty but the coffee is too sw...
# 3          Cleaning was not good, very dirty tables.
#
#                                            processed
# 0           the food was amazing and the tea was hot
# 1     bad service i waited 20 minutes for a sandwich
# 2  the samosas are tasty but the coffee is too sweet
# 3            cleaning was not good very dirty tables

# %%
df['tokens'] = df['processed'].apply(lambda x: word_tokenize(x))
df
# Out:
#                                             raw_text  \
# 0       The food was amazing, and the tea was hot!!!
# 1  Bad service... I waited 20 minutes for a sandw...
# 2  The samosas are tasty but the coffee is too sw...
# 3          Cleaning was not good, very dirty tables.
#
#                                            processed  \
# 0           the food was amazing and the tea was hot
# 1     bad service i waited 20 minutes for a sandwich
# 2  the samosas are tasty but the coffee is too sweet
# 3            cleaning was not good very dirty tables
#
#                                               tokens
# 0  [the, food, was, amazing, and, the, tea, was, ...
# 1  [bad, service, i, waited, 20, minutes, for, a,...
# 2  [the, samosas, are, tasty, but, the, coffee, i...
# 3    [cleaning, was, not, good, very, dirty, tables]

# %%
stop_words = set(stopwords.words('english'))

df['no_words'] = df['tokens'].apply(lambda x: [word for word in x if word not in stop_words])
df
# Out:
#                                             raw_text  \
# 0       The food was amazing, and the tea was hot!!!
# 1  Bad service... I waited 20 minutes for a sandw...
# 2  The samosas are tasty but the coffee is too sw...
# 3          Cleaning was not good, very dirty tables.
#
#                                            processed  \
# 0           the food was amazing and the tea was hot
# 1     bad service i waited 20 minutes for a sandwich
# 2  the samosas are tasty but the coffee is too sweet
# 3            cleaning was not good very dirty tables
#
#                                               tokens  \
# 0  [the, food, was, amazing, and, the, tea, was, ...
# 1  [bad, service, i, waited, 20, minutes, for, a,...
# 2  [the, samosas, are, tasty, but, the, coffee, i...
# 3    [cleaning, was, not, good, very, dirty, tables]
#
#                                         no_words
# 0                      [food, amazing, tea, hot]
# 1  [bad, service, waited, 20, minutes, sandwich]
# ...

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

df['stemmed'] = df['no_words'].apply(lambda x: [stemmer.stem(word) for word in x])
df['lemmatized'] = df['no_words'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

df
# Out:
#                                             raw_text  \
# 0       The food was amazing, and the tea was hot!!!
# 1  Bad service... I waited 20 minutes for a sandw...
# 2  The samosas are tasty but the coffee is too sw...
# 3          Cleaning was not good, very dirty tables.
#
#                                            processed  \
# 0           the food was amazing and the tea was hot
# 1     bad service i waited 20 minutes for a sandwich
# 2  the samosas are tasty but the coffee is too sweet
# 3            cleaning was not good very dirty tables
#
#                                               tokens  \
# 0  [the, food, was, amazing, and, the, tea, was, ...
# 1  [bad, service, i, waited, 20, minutes, for, a,...
# 2  [the, samosas, are, tasty, but, the, coffee, i...
# 3    [cleaning, was, not, good, very, dirty, tables]
#
#                                         no_words  stemmer lemmatizer  \
# 0                      [food, amazing, tea, hot]  no_word   no_words
# ...

# %%
df['cleaned'] = df['lemmatized'].apply(lambda x: " ".join(x))

# %%
cv = CountVectorizer()

df_bow = cv.fit_transform(df['cleaned'])
vocab = cv.get_feature_names_out()
